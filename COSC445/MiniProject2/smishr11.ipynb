# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac22mp2']
coll = db ['audris']
# for each dataset
coll.insert_one ( { 'owner':'audris', 'topic':'git URLs', 'first dataset': 'largest projects', 'license': 'NA', 'description': 'The list of projects on github with the largest number of stars', 'urls': [ 'url1', 'url2' ] } )
# Out:
# ObjectId('5d7e6769e1eaff62f15de0d2')

# %%
import pprint
import pymongo, json
client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac22mp2']
coll = db ['audris']
pp = pprint.PrettyPrinter(indent=1,width=65)
for r in coll. find({'owner'='audris'}):
  print(pp .pformat (r))
# Out:
# {'_id': ObjectId('5d7e6769e1eaff62f15de0d2'),
#  'description': 'The list of projects on github with the '
#                 'largest number of stars',
#  'first dataset': 'largest projects',
#  'license': 'NA',
#  'topic': 'git URLs',
#  'urls': ['url1', 'url2']}

# %%
import pprint
import re
import pymongo, json

pp = pprint.PrettyPrinter(indent=1,width=65)

client = pymongo.MongoClient (host="da1.eecs.utk.edu")
db = client ['fdac22mp2']
coll = db ['smishr11']
# for each dataset
coll.insert_one ( { #1
    'owner':'smishr11', 
    'topic':'Whistleblowers', 
    'title': 'Whistleblower statistics 2020 to 2021', 
    'license': 'Open Government Licence v3.0', 
    'description': 'The CMA is a listed organisation included in the Prescribed Persons Order 2014, which provides the statutory framework for protecting persons from harm if they report on any wrongdoing involving their employer. The process by which a person may make this report is referred to as “making a disclosure” or “whistleblowing”.', 
    'urls': [ 'https://www.gov.uk/government/publications/whistleblower-statistics-2020-to-2021/whistleblowing-statistics-2020-to-2021' ] } )
coll.insert_one ( { #2
    'owner':'smishr11', 
    'topic':'Whistleblowers', 
    'title': 'Institutional organization of whistleblowers in Italy 2020', 
    'license': 'N/A', 
    'description': 'In Italy, 44.7 percent of reported complaints were made by whistleblowers working for regional and local authorities. Moreover, data regarding 2020 showed that 21.8 percent of whistleblowers were employed in other administration and public authorities such as ministries, social security authorities, independent authorities, public agencies, and other. In Italy, the complaints of irregularities within the public administration are collected by ANAC, the National Anti-Corruption Authority. In 2020, 622 whistleblowing complaints were made in Italy.', 
    'urls': [ 'https://www.statista.com/statistics/1060278/institutional-organization-of-whistleblowers-in-italy/' ] } )
coll.insert_one ( { #3
    'owner':'smishr11', 
    'topic':'Whistleblowers',  
    'title': 'Whistleblower statistics 2019 to 2020', 
    'license': 'Open Government Licence v3.0', 
    'description': 'The CMA is a listed organisation included in the Prescribed Persons Order 2014, which provides the statutory framework for protecting persons from harm if they report on any wrongdoing involving their employer. The process by which a person may make this report is referred to as “making a disclosure” or “whistleblowing”.', 
    'urls': [ 'https://www.gov.uk/government/publications/whistleblower-statistics-2019-to-2020' ] } )
coll.insert_one ( { #4
    'owner':'smishr11', 
    'topic':'Whistleblowers',
    'title': 'Whistleblowers Disclosure', 
    'license': 'N/A', 
    'description': 'Number of occasions on which public interest information has been disclosed to a responsible officer of the agency under the Whistleblowers Protection Act 1993 Number of occasions on which public interest information has been disclosed to a responsible officer of the agency under the Whistleblowers Protection Act 1993', 
    'urls': [ 'https://data.gov.au/dataset/ds-sa-90594739-7abe-4534-812c-dbdaa8035661/details' ] } )
coll.insert_one ( { #5
    'owner':'smishr11', 
    'topic':'Whistleblowers',
    'title': 'Number of whistleblowing cases in Italy 2015-2020', 
    'license': 'N/A', 
    'description': 'Between 2015 and 2019, the number of whistleblowing complaints registered in Italy by ANAC significantly increased. ANAC is the National Anti-Corruption Authority and it collects reports of irregularities within the public administration. As of 2015, 125 cases were recorded nationwide. In 2019, the National Anti-Corruption Authority received 873 notifications by whistleblowers, while 622 cases were recorded in 2020, a decrease compared to 2019. Whistleblowing complaints took place mainly in the South of Italy, where almost half of the reports came from.', 
    'urls': [ 'https://www.statista.com/statistics/1060165/number-of-whistleblowing-cases-in-italy/' ] } )
coll.insert_one ( { #6
    'owner':'smishr11', 
    'topic':'Whistleblowers',
    'title': 'Whistleblower', 
    'license': 'N/A', 
    'description': 'OSHA administers 23 whistleblower statutes. The agency has an online complaint that gathers information about adverse actions, potential reasons for adverse actions, dates of adverse actions, and establishment identifying information including location, and contact information. All is included in a database and supplemented by complaint information that is collected by other means, and data that is collected during investigations. The additional data gathered from the public includes greater depth on allegations, type of complaint, and in some cases -- appeals. The Privacy Act controls much of what is released to the public, and the agency also follows a system of records notice, which leads to the aggregation of data on docketed cases and complaint determinations by statute, which are released to the public.', 
    'urls': [ 'https://catalog.data.gov/dataset/whistleblower-749b9' ] } )
coll.insert_one ( { #7
    'owner':'smishr11', 
    'topic':'Whistleblowers',
    'title': 'Distribution of whistleblowing cases in Italy 2020, by type', 
    'license': 'N/A', 
    'description': 'In 2020, discriminatory measures adopted by the administration or the authority were the most common irregularities exposed by whistleblowers within the Italian public administration. In fact, ANAC, the National Anti-Corruption Authority, reported that such complaints accounted for 23.5 percent of the total. Furthermore, corruption, maladministration, and misuse of power accounted for 19.5 percent of whistleblowing cases, the second most denounced incorrect behavior.', 
    'urls': [ 'https://www.statista.com/statistics/1060222/distribution-of-whistleblowing-cases-by-type-in-italy-2019/' ] } )
coll.insert_one ( { #8
    'owner':'smishr11', 
    'topic':'Whistleblowers',
    'title': 'Whistleblower statistics 2017 to 2018', 
    'license': 'Open Government Licence v3.0', 
    'description': 'The CMA is a listed organisation included in the Prescribed Persons Order 2014, which provides the statutory framework for protecting persons from harm if they report on any wrongdoing involving their employer. The process by which a person may make this report is referred to as “making a disclosure” or “whistleblowing”', 
    'urls': [ 'https://www.gov.uk/government/publications/whistleblower-statistics-2017-to-2018' ] } )
coll.insert_one ( { #9
    'owner':'smishr11', 
    'topic':'Whistleblowers',
    'title': 'Whistleblower Report', 
    'license': 'Open Government Licence 3.0', 
    'description': 'Dataset published by Lincolnshire County Council showing the number of Whistleblower reports received, and the number that resulted in investigations', 
    'urls': [ 'https://www.data.gov.uk/dataset/7fa85749-76ab-4e79-84a2-dd7b65ecad9f/whistleblower-report' ] } )
coll.insert_one ( { #10
    'owner':'smishr11', 
    'topic':'Whistleblowers', 
    'title': 'Data from: Whistleblowers Protection Act', 
    'license': 'Attribution 3.0 (CC BY 3.0)', 
    'description': 'Whistleblowers Protection Act', 
    'urls': [ 'https://data.wu.ac.at/schema/data_gov_au/ZjI2NGQ1MTctNDU3MS00NjU5LWIzYmUtZmQwYWQzYjQ4YWNl' ] } )
coll.insert_one ( { #11
    'owner':'smishr11', 
    'topic':'Whistleblowers', 
    'title': 'Whistleblowers Disclosure', 
    'license': 'Attribution 4.0 (CC BY 4.0)', 
    'description': 'Number of occasions on which public interest information has been disclosed to a responsible officer of the agency under the Whistleblowers Protection Act 1993 for the period 2012-13 to 2016-17', 
    'urls': [ 'https://data.wu.ac.at/schema/data_sa_gov_au/OTA1OTQ3MzktN2FiZS00NTM0LTgxMmMtZGJkYWE4MDM1NjYx' ] } )
coll.insert_one ( { #12
    'owner':'smishr11', 
    'topic':'Whistleblowers', 
    'title': 'DHS Annual Report Data - Whistleblowers Disclosure', 
    'license': 'https://data.sa.gov.au/data/dataset/8c91cc5d-d1eb-4aa7-ba80-14effb471465', 
    'description': 'DHS Annual Report data on: Number of occasions on which public interest information has been disclosed to a responsible officer of the agency under the Whistleblowers Protection Act 1993 Dataset …Show full descriptionDHS Annual Report data on: Number of occasions on which public interest information has been disclosed to a responsible officer of the agency under the Whistleblowers Protection Act 1993 Dataset includes: Data from 2012-13 financial year through to 2018-19 financial year Includes data from predecessor agency Department for Communities and Social Inclusion (DCSI).', 
    'urls': [ 'https://data.gov.au/dataset/ds-sa-8c91cc5d-d1eb-4aa7-ba80-14effb471465/details' ] } )
coll.insert_one ( { #13
    'owner':'smishr11', 
    'topic':'Whistleblowers', 
    'title': 'FCA: Whistleblowing quarterly data 2021 Q3', 
    'license': 'Open Government Licence 3.0', 
    'description': 'The data shows the number of new whistleblowing reports the FCA received in July to September 2021 and the allegations they featured. The FCA Whistleblowing team receives reports about alleged wrongdoing in the areas of financial services that fall within its remit. The FCA assesses every whistleblowing case it receives, to inform the work it does and to help it to identify actual or potential harm that has arisen or could arise. This could be harm to consumers, to markets, to the UK economy or to wider society. Deciding to blow the whistle is a brave act and the FCA greatly value the information it receives from whistleblowers.', 
    'urls': [ 'https://www.data.gov.uk/dataset/5038a517-bf07-432e-bb5d-8f9e11638e54/fca-whistleblowing-quarterly-data-2021-q3' ] } )
coll.insert_one ( { #14
    'owner':'smishr11', 
    'topic':'Whistleblowers', 
    'title': 'Whistleblower Protection Program', 
    'license': 'N/A', 
    'description': 'The Whistleblower Protection Program (WBPP) (49 U.S.C. § 4 1 1) protects individuals from employment discrimination for alleged violations of Federal Aviation Regulations or other Federal laws pertaining to air carrier safety.', 
    'urls': [ 'https://datahub.transportation.gov/Administrative/Whistleblower-Protection-Program-/aa7g-9q9e' ] } )
coll.insert_one ( { #15
    'owner':'smishr11', 
    'topic':'Whistleblowers', 
    'title': 'Primary purposes of whistleblowing programs in the UK financial service industry 2016', 
    'license': 'N/A', 
    'description': 'This statistic shows what financial service industry employees and board members believe to be the primary purposes of whistleblowing programs in the UK. Both employees and the board share the idea that the most important primary purpose for the new whistleblowing program is to promote an ethical organizational culture with 47 percent of employees and 52 percent of board members agreeing with this statement.', 
    'urls': [ 'https://www.statista.com/statistics/744222/primary-purposes-of-whistleblowing-programs-uk/' ] } )
coll.insert_one ( { #16
    'owner':'smishr11', 
    'topic':'Whistleblowers', 
    'title': 'Department of State Development - Whistleblowers Disclosure', 
    'license': 'N/A', 
    'description': 'Reporting against the Whistleblowers Protection Act 1993 by the Department of State Development. Reporting against the Whistleblowers Protection Act 1993 by the Department of State Development.', 
    'urls': [ 'https://data.gov.au/dataset/ds-sa-5e4f117a-20c2-49e3-a0af-55cb930efc90/details' ] } )
coll.insert_one ( { #17
    'owner':'smishr11', 
    'topic':'Whistleblowers',
    'title': 'NATIONAL WHISTLEBLOWER CENTER, fiscal year ending Dec. 2020', 
    'license': 'N/A', 
    'description': 'ProPublicas Nonprofit Explorer lets you view summaries of 2.2 million tax returns from tax-exempt organizations and see financial details such as their executive compensation and revenue and expenses. You can browse raw IRS data released since 2013 and access over 9.4 million tax filing documents going back as far as 2001.', 
    'urls': [ 'https://projects.propublica.org/nonprofits/organizations/521770068' ] } )
coll.insert_one ( { #18
    'owner':'smishr11', 
    'topic':'Whistleblowers', 
    'title': 'Replication Data for: Signaling and Counter-Signaling in the Judicial Hierarchy: An Empirical Analysis of En Banc Review', 
    'license': 'https://dataverse.harvard.edu/api/datasets/:persistentId/versions/1.4/customlicense?persistentId=doi:10.7910/DVN/2EJIZJ', 
    'description': 'We leverage the institutional features of American courts to evaluate the importance of whistleblowers in hierarchical oversight. Drawing on a formal theory of signaling in the judicial hierarchy, we examine the role of whistleblowing dissents in triggering en banc review of three-judge panels by full circuits of the Courts of Appeals. The theory generates predictions about how dissent interacts with judicial preferences to influence circuits' review and reversal decisions, which we test using original and existing data. First, we show that judges who dissent counter to their preferences are more likely to see their dissents lead to review and reversal. Second, we show that dissents are most influential when the likelihood of non-compliance by a three-judge panel is highest. Our results underscore the importance of dissent in the judicial hierarchy and illustrate how judicial whistleblowers can help appellate courts target the most important cases for review.', 
    'urls': [ 'https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/2EJIZJ' ] } )
coll.insert_one ( { #19
    'owner':'smishr11', 
    'topic':'Whistleblowers', 
    'title': 'FCA: Whistleblowing quarterly data 2021 Q4', 
    'license': 'Open Government Licence 3.0', 
    'description': 'The data shows the number of new whistleblowing reports the FCA received in October and December 2021 and the allegations they featured.The FCA Whistleblowing team receives reports about alleged wrongdoing in the areas of financial services that fall within its remit.The FCA assesses every whistleblowing case it receives, to inform the work it does and to help it to identify actual or potential harm that has arisen or could arise. This could be harm to consumers, to markets, to the UK economy or to wider society. The Whistleblowing team receives reports by telephone, email, our online reporting form and post. In 2021 Q4 (October-December), the FCA received 279 new whistleblowing reports.', 
    'urls': [ 'https://www.data.gov.uk/dataset/19dc778c-29be-4311-a01e-2f9cc662bf62/fca-whistleblowing-quarterly-data-2021-q4' ] } )
coll.insert_one ( { #20
    'owner':'smishr11', 
    'topic':'Whistleblowers', 
    'title': 'Distribution of whistleblowing cases by macro-region in Italy 2020', 
    'license': 'NA', 
    'description': 'In 2020, the number of whistleblowing complaints registered in Italy by ANAC amounted to 622. ANAC is the National Anti-Corruption Authority and it collects reports of irregularities within the public administration. That year, almost half of the cases of whistleblowing (46 percent) were reported in the South. By contrast, 21 percent of irregularities were registered in the Center, the lowest percentage nationwide.', 
    'urls': [ 'https://www.statista.com/statistics/1060199/distribution-of-whistleblowing-cases-by-macro-region-in-italy/' ] } )
